# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51263/RL-Lab/blob/main/Lab-06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -22343
# Average Reward: -10.41
#
# Episode: 2
# Total Reward: -2829
# Average Reward: -7.99
#
# Episode: 3
# Total Reward: -77499
# Average Reward: -9.57
#
# Episode: 4
# Total Reward: -18459
# Average Reward: -9.58
#
# Episode: 5
# Total Reward: -57828
# Average Reward: -10.05
#
# Taxi Environment
# Episode: 1
# Total Reward: -875
# Average Reward: -4.38
#
# Episode: 2
# Total Reward: -767
# Average Reward: -3.83
#
# Episode: 3
# Total Reward: -758
# Average Reward: -3.79
#
# Episode: 4
# Total Reward: -704
# Average Reward: -3.52
#
# Episode: 5
# Total Reward: -71
# Average Reward: -2.45
